# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### 01. heart.csv

# %%
df = pd.read_csv('heart.csv')
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %% [markdown]
# #### 연속형 히스토그램

# %% [markdown]
# ### 나이 데이터
#
# 정규분포

# %%
sns.histplot(data=df, x = 'age')
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %% [markdown]
# ### 안정시 혈압 측정값
#
# 1. 이상치를 빼고 생각하면 감마, 카이제곱 분포
# 2. 이상치 추가해서 생각하면 정규분포

# %%
sns.histplot(data=df, x = 'trestbps')
# Out:
# <Axes: xlabel='trestbps', ylabel='Count'>

# %% [markdown]
# ### 콜레스테롤 측정값
#
#  500이 넘어가는 이상치를 제외 정규분포
#  * 하지만 의학적 데이터 이기에 이상치를 제거하면 안된다.
#
#  (이상치 포함)
#  1. 감마 분포
#  2. 카이제곱 분포

# %%
sns.histplot(data=df, x = 'chol')
# Out:
# <Axes: xlabel='chol', ylabel='Count'>

# %% [markdown]
# ### 혈액 장애값
#
# 1. 알파 값을 엄청 크게 잡으면 감마분포 가능
# 2. 베타분포

# %%
sns.histplot(data=df, x = 'thalach')
# Out:
# <Axes: xlabel='thalach', ylabel='Count'>

# %% [markdown]
# ### 심전도 파형
#
# 지수 함수

# %%
sns.histplot(data=df, x = 'oldpeak')
# Out:
# <Axes: xlabel='oldpeak', ylabel='Count'>

# %% [markdown]
# #### 범주형 히스토그램

# %%
#범주형 필드 

# 흉통 유형 (무증상, 비정형 협심증, 비협심증 통증, 전형적 협심증)
sns.countplot( x = 'cp', data=df)
# Out:
# <Axes: xlabel='cp', ylabel='count'>

# %%
#성별
# 0 = 남성, 1 = 여성
sns.countplot( x = 'sex', data=df)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.countplot( x = 'fbs', data=df)
# Out:
# <Axes: xlabel='fbs', ylabel='count'>

# %%
sns.countplot( x = 'restecg', data=df)
# Out:
# <Axes: xlabel='restecg', ylabel='count'>

# %%
#운동 유발 협심증 
sns.countplot( x = 'exang', data=df)
# Out:
# <Axes: xlabel='exang', ylabel='count'>

# %%
sns.countplot( x = 'slope', data=df)
# Out:
# <Axes: xlabel='slope', ylabel='count'>

# %%
sns.countplot( x = 'ca', data=df)
# Out:
# <Axes: xlabel='ca', ylabel='count'>

# %% [markdown]
# ### 02. wine_data.csv

# %%
df_2 = pd.read_csv('wine_data.csv')
df_2
# Out:
#      Alcohol  Malic   Ash  Alcalinity  Magesium  Phenols  Flavanoids  \
# 0      14.23   1.71  2.43        15.6       127     2.80        3.06
# 1      13.20   1.78  2.14        11.2       100     2.65        2.76
# 2      13.16   2.36  2.67        18.6       101     2.80        3.24
# 3      14.37   1.95  2.50        16.8       113     3.85        3.49
# 4      13.24   2.59  2.87        21.0       118     2.80        2.69
# ..       ...    ...   ...         ...       ...      ...         ...
# 173    13.71   5.65  2.45        20.5        95     1.68        0.61
# 174    13.40   3.91  2.48        23.0       102     1.80        0.75
# 175    13.27   4.28  2.26        20.0       120     1.59        0.69
# 176    13.17   2.59  2.37        20.0       120     1.65        0.68
# 177    14.13   4.10  2.74        24.5        96     2.05        0.76
#
#      Nonflavanoids  Proanthocyanins  Color   Hue  Dilution  Proline  class
# ...

# %% [markdown]
# #### 연속형 히스토그램

# %%
#알콜
sns.histplot(data = df_2, x = 'Alcohol')
# Out:
# <Axes: xlabel='Alcohol', ylabel='Count'>

# %%
#말산
sns.histplot(data = df_2, x = 'Malic')
# Out:
# <Axes: xlabel='Malic', ylabel='Count'>

# %%
#회분
sns.histplot(data = df_2, x = 'Ash')
# Out:
# <Axes: xlabel='Ash', ylabel='Count'>

# %%
#마그네슘
sns.histplot(data = df_2, x = 'Magesium')
# Out:
# <Axes: xlabel='Magesium', ylabel='Count'>

# %%
#회분의 알칼리도
sns.histplot(data = df_2, x = 'Alcalinity')
# Out:
# <Axes: xlabel='Alcalinity', ylabel='Count'>

# %%
#총 폴리페놀
sns.histplot(data = df_2, x = 'Phenols')
# Out:
# <Axes: xlabel='Phenols', ylabel='Count'>

# %%
# 플라보노이드 폴리페놀
sns.histplot(data = df_2, x = 'Flavanoids')
# Out:
# <Axes: xlabel='Flavanoids', ylabel='Count'>

# %%
#비 플라보노이드 폴리페놀
sns.histplot(data = df_2, x = 'Nonflavanoids')
# Out:
# <Axes: xlabel='Nonflavanoids', ylabel='Count'>

# %%
#프로안토시아닌
sns.histplot(data = df_2, x = 'Proanthocyanins')
# Out:
# <Axes: xlabel='Proanthocyanins', ylabel='Count'>

# %%
#색상ㄷ의 강도
sns.histplot(data = df_2, x = 'Color')
# Out:
# <Axes: xlabel='Color', ylabel='Count'>

# %%
#색상
sns.histplot(data = df_2, x = 'Hue')
# Out:
# <Axes: xlabel='Hue', ylabel='Count'>

# %%
#희석 와인의 비율
sns.histplot(data = df_2, x = 'Dilution')
# Out:
# <Axes: xlabel='Dilution', ylabel='Count'>

# %%
#프롤린
sns.histplot(data = df_2, x = 'Proline')
# Out:
# <Axes: xlabel='Proline', ylabel='Count'>
